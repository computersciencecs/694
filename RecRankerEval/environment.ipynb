# %%
# !pip list
# Out:
# Package                           Version
# --------------------------------- --------------
# accelerate                        1.0.1
# aiohttp                           3.9.5
# aiosignal                         1.3.1
# annotated-types                   0.7.0
# anyio                             4.3.0
# archspec                          0.2.1
# argon2-cffi                       23.1.0
# argon2-cffi-bindings              21.2.0
# arrow                             1.3.0
# asttokens                         2.0.5
# astunparse                        1.6.3
# async-lru                         2.0.4
# async-timeout                     4.0.3
# attrs                             23.1.0
# Babel                             2.15.0
# beautifulsoup4                    4.12.2
# bitsandbytes                      0.43.1
# bleach                            6.1.0
# boltons                           23.0.0
# Brotli                            1.0.9
# certifi                           2023.11.17
# ...
